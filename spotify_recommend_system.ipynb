# %% [markdown]
# ## 獲取Spotify auth_token

# %%
import re
import urllib.parse
import requests
import base64
import pandas as pd
from datetime import datetime

pd.set_option('display.max_columns', None)


def get_auth_url(client_id, redirect_uri):
    scope = 'user-read-private user-read-email user-top-read user-library-read'
    
    auth_url_params = {
        'client_id': client_id,
        'response_type': 'code',
        'scope': scope,
        'redirect_uri': redirect_uri,
        'show_dialog': 'true'
    }

    auth_url = f'https://accounts.spotify.com/authorize?{urllib.parse.urlencode(auth_url_params)}'
    
    return f'請訪問此URL以授權應用程式：{auth_url}'

def exchange_code_for_tokens(auth_code, client_id, client_secret, redirect_uri):
    credentials = f"{client_id}:{client_secret}"
    encoded_credentials = base64.b64encode(credentials.encode()).decode()

    token_url = 'https://accounts.spotify.com/api/token'
    token_data = {
        'grant_type': 'authorization_code',
        'code': auth_code,
        'redirect_uri': redirect_uri
    }
    token_headers = {
        'Authorization': f'Basic {encoded_credentials}',
        'Content-Type': 'application/x-www-form-urlencoded'
    }

    response = requests.post(token_url, headers=token_headers, data=token_data)
    if response.status_code == 200:
        tokens = response.json()
        return tokens
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return None

def refresh_access_token(refresh_token, client_id, client_secret):
    credentials = f"{client_id}:{client_secret}"
    encoded_credentials = base64.b64encode(credentials.encode()).decode()

    token_url = 'https://accounts.spotify.com/api/token'
    token_data = {
        'grant_type': 'refresh_token',
        'refresh_token': refresh_token
    }
    token_headers = {
        'Authorization': f'Basic {encoded_credentials}',
        'Content-Type': 'application/x-www-form-urlencoded'
    }

    response = requests.post(token_url, headers=token_headers, data=token_data)
    if response.status_code == 200:
        tokens = response.json()
        return tokens['access_token']
    else:
        print(f"Error: {response.status_code} - {response.text}")
        return None

# %%
client_id = '341fbb565d4041038d2e71a52e9b5fa6'
client_secret = '1585574761444a178c4c67751840535a'
redirect_uri = 'https://github.com/SamHuang1018'

# 第一次先手動獲取auth_code
auth_url = get_auth_url(client_id, redirect_uri)
auth_url
# Out:
# '請訪問此URL以授權應用程式：https://accounts.spotify.com/authorize?client_id=341fbb565d4041038d2e71a52e9b5fa6&response_type=code&scope=user-read-private+user-read-email+user-top-read+user-library-read&redirect_uri=https%3A%2F%2Fgithub.com%2FSamHuang1018&show_dialog=true'

# %%
url = 'https://github.com/SamHuang1018?code=AQDFeigDKiBrVQO8CygiHaJfqvT-CF9wkoGOdDtMKafyXVdT_0JgJoT4-KDUreyIoqSJ9W3Lms0PFTYCVvB4O-tppBMN8lIaD6DlCnb6S0Fw4Uennt8GJAQxXP0YzVJdAncnaK9x4dYZsIB4bxUx18CeIAYvLiAAKiBwH4NjBEbAffYCceiQXsOKVVBQsANaXox5vslCPZCcYrSaXFuLgsayD1WaaCoBg3U3jyVlBgMDFUcnVf-FOsMdjkEJFDKmo8IQ0bArWHnc'
match = re.search(r'code=([\w-]+)', url)
auth_code = match.group(1)

tokens = exchange_code_for_tokens(auth_code, client_id, client_secret, redirect_uri)
session = {
    'access_token': tokens['access_token'],
    'expires_at': datetime.now().timestamp() + tokens['expires_in'],
    'refresh_token': tokens['refresh_token']
}

# %%
access_token = refresh_access_token(session['refresh_token'], client_id, client_secret)
print(f"刷新後新Token: {access_token}")
# Out:
# 刷新後新Token: BQAzVoxh7QJEUTsMeXg993kkeM2XQzyIBSafeA6NdK8o7hQn4HxgmGaZHOeRpPEgFBfa-CMRFLJcXok7xuLQNAjg15bEaFnw3q5kJYi1t2hazboRtxDmO8gOxsBMP1pJZVkUd6vCD4ZcSW5X9PcTKBHV_xKAZhycfOdIhEDJmrvP-b03EDdbV45CHqa69MxFO7rPIdqxioj7RBqtZEyZeQ-Ef8oufQ

# %% [markdown]
# ## Spotify API

# %% [markdown]
# #### 串接起始值

# %%
def spotify_request(endpoint):
    global access_token
    if datetime.now() > datetime.fromtimestamp(session['expires_at']):
        refresh_access_token()
    
    headers = {'Authorization': f'Bearer {access_token}'}
    
    data = []
    limit = 50
    offset = 0
    total_tracks = requests.get('https://api.spotify.com/v1/' + endpoint + f'?limit={limit}&offset={offset}', headers=headers).json()['total']

    # while offset < total_tracks:
    #     url = 'https://api.spotify.com/v1/' + endpoint + f'?limit={limit}&offset={offset}'
    #     print(url)
    #     response = requests.get(url, headers=headers).json()
    #     data.extend(response['items'])
    #     offset += limit
    #     print(offset, limit)

    for offset in range(0, total_tracks, limit):
        url = 'https://api.spotify.com/v1/' + endpoint + f'?limit={limit}&offset={offset}'
        # print(url)
        response = requests.get(url, headers=headers).json()
        data.extend(response['items'])
    
    return data

# %%
playlists = spotify_request('playlists/2YcZP6aa6osb8XSdIGyJUm/tracks')
top_artists = spotify_request('me/top/artists')
top_tracks = spotify_request('me/top/tracks')
print(f'總共曲目: {len(playlists)}')
print(f'總共熱門藝人: {len(top_artists)}')
print(f'總共熱門專輯: {len(top_tracks)}')
# Out:
# 總共曲目: 642
# 總共熱門藝人: 114
# 總共熱門專輯: 1343

# %% [markdown]
# #### 播放清單

# %%
columns = [
    'added_at', 'added_by', 'is_local', 'primary_color', 'track_preview_url',
    'track_available_markets', 'explicit', 'track_type', 'episode', 
    'album_available_markets', 'album_type',  'album_href',
    'album_id', 'album_image_url', 'album_name', 'album_release_date',
    'album_release_date_precision', 'album_uri', 'album_artists',
    'album_external_urls', 'album_total_tracks', 'artists', 'disc_number',
    'track_number', 'duration_ms', 'external_ids_isrc', 'external_urls_spotify',
    'track_href', 'track_id', 'track_name', 'track_popularity', 'track_uri',
    'video_thumbnail_url'
]
playlists_df = pd.DataFrame(columns=columns)

def extract_track_info(track_item):
    track = track_item.get('track', {})
    album = track.get('album', {})
    
    return {
        'added_at': track_item.get('added_at'),
        'added_by': track_item.get('added_by', {}).get('id'),
        'is_local': track_item.get('is_local'),
        'primary_color': track_item.get('primary_color'),
        'track_preview_url': track.get('preview_url'),
        'track_available_markets': track.get('available_markets'),
        'explicit': track.get('explicit'),
        'track_type': track.get('type'),
        'episode': track.get('episode'),
        'album_available_markets': album.get('available_markets'),
        'album_type': album.get('album_type'),
        'album_href': album.get('href'),
        'album_id': album.get('id'),
        'album_image_url': album.get('images', [{}])[0].get('url') if album.get('images') else None,
        'album_name': album.get('name'),
        'album_release_date': album.get('release_date'),
        'album_release_date_precision': album.get('release_date_precision'),
        'album_uri': album.get('uri'),
        'album_artists': [artist['name'] for artist in album.get('artists', [])],
        'album_external_urls': album.get('external_urls', {}).get('spotify'),
        'album_total_tracks': album.get('total_tracks'),
        'artists': [artist['name'] for artist in track.get('artists', [])],
        'disc_number': track.get('disc_number'),
        'track_number': track.get('track_number'),
        'duration_ms': track.get('duration_ms'),
        'external_ids_isrc': track.get('external_ids', {}).get('isrc'),
        'external_urls_spotify': track.get('external_urls', {}).get('spotify'),
        'track_href': track.get('href'),
        'track_id': track.get('id'),
        'track_name': track.get('name'),
        'track_popularity': track.get('popularity'),
        'track_uri': track.get('uri'),
        'video_thumbnail_url': track_item.get('video_thumbnail', {}).get('url')
    }

playlist_data = [extract_track_info(track_item) for track_item in playlists]
playlists_df = pd.DataFrame(playlist_data, columns=columns)
playlists_df['duration_ms'] = pd.to_timedelta(playlists_df['duration_ms'], unit='ms').apply(lambda x: f"{x.components.minutes}m {x.components.seconds}s")

display(playlists_df)
# Out:
#                  added_at     added_by  is_local primary_color  \
# 0    2022-07-28T15:41:21Z  11124654085     False          None
# 1    2022-07-29T02:28:48Z  11124654085     False          None
# 2    2022-07-29T02:28:55Z  11124654085     False          None
# 3    2022-07-29T02:29:05Z  11124654085     False          None
# 4    2022-07-29T02:29:12Z  11124654085     False          None
# ..                    ...          ...       ...           ...
# 637  2024-03-31T04:19:47Z  11124654085     False          None
# 638  2024-03-31T17:30:23Z  11124654085     False          None
# 639  2024-04-26T02:05:55Z  11124654085     False          None
# 640  2024-05-09T03:29:03Z  11124654085     False          None
# 641  2024-05-09T03:32:06Z  11124654085     False          None
#
#                                      track_preview_url  \
# 0    https://p.scdn.co/mp3-preview/22eb68cc3789f115...
# 1    https://p.scdn.co/mp3-preview/82a8c178625c7776...
# 2    https://p.scdn.co/mp3-preview/6d2440374a5a7d2a...
# 3    https://p.scdn.co/mp3-preview/5262679961609398...
# 4    https://p.scdn.co/mp3-preview/743e653c838a411c...
# ..                                                 ...
# 637  https://p.scdn.co/mp3-preview/fac686f4d6745354...
# 638  https://p.scdn.co/mp3-preview/1d60ab8c89d67e05...
# 639  https://p.scdn.co/mp3-preview/95743de0aed23b31...
# 640  https://p.scdn.co/mp3-preview/d712bb7446055edc...
# 641  https://p.scdn.co/mp3-preview/55637da466ac58e5...
#
#                                track_available_markets  explicit track_type  \
# 0                                                   []     False      track
# 1    [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...     False      track
# 2    [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...     False      track
# 3    [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...     False      track
# 4    [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...     False      track
# ..                                                 ...       ...        ...
# 637  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...     False      track
# 638  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...     False      track
# 639  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...     False      track
# 640  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...     False      track
# 641  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...     False      track
#
#      episode                            album_available_markets album_type  \
# 0      False                                                 []     single
# 1      False  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...      album
# 2      False  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...      album
# 3      False  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...      album
# 4      False  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...      album
# ..       ...                                                ...        ...
# 637    False  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...      album
# 638    False  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...      album
# 639    False  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...      album
# 640    False  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...      album
# 641    False  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...     single
#
#                                             album_href  \
# 0    https://api.spotify.com/v1/albums/32VfvVGwzuka...
# 1    https://api.spotify.com/v1/albums/0kVzT55moiHL...
# 2    https://api.spotify.com/v1/albums/42VABZoODED0...
# 3    https://api.spotify.com/v1/albums/052EiTRYh35M...
# 4    https://api.spotify.com/v1/albums/4tg1ZCJOqMRJ...
# ..                                                 ...
# 637  https://api.spotify.com/v1/albums/3k7bXPw2u0C0...
# 638  https://api.spotify.com/v1/albums/6Ar5HxNWXtvr...
# 639  https://api.spotify.com/v1/albums/1tZ4awYGvCSG...
# 640  https://api.spotify.com/v1/albums/5eH0FIug3Plo...
# 641  https://api.spotify.com/v1/albums/4NRsGHlWBTl4...
#
#                    album_id  \
# 0    32VfvVGwzuka6xQSrdyamD
# 1    0kVzT55moiHLN4Yr3rDGRw
# 2    42VABZoODED0S2Ne4zLCUc
# 3    052EiTRYh35MuDVJN9Emdh
# 4    4tg1ZCJOqMRJAnGT9WdWV7
# ..                      ...
# 637  3k7bXPw2u0C0SBKPMsgMS3
# 638  6Ar5HxNWXtvraqs7FI7bYq
# 639  1tZ4awYGvCSGXEUskU7tPY
# 640  5eH0FIug3PloCIxe0fqMFI
# 641  4NRsGHlWBTl4rdLcq8CKcH
#
#                                        album_image_url  \
# 0    https://i.scdn.co/image/ab67616d0000b273eb62b8...
# 1    https://i.scdn.co/image/ab67616d0000b273fbffbf...
# 2    https://i.scdn.co/image/ab67616d0000b2735b972f...
# 3    https://i.scdn.co/image/ab67616d0000b273775e81...
# 4    https://i.scdn.co/image/ab67616d0000b273510baa...
# ..                                                 ...
# 637  https://i.scdn.co/image/ab67616d0000b2735da275...
# 638  https://i.scdn.co/image/ab67616d0000b273bc16d1...
# 639  https://i.scdn.co/image/ab67616d0000b273b5c00f...
# 640  https://i.scdn.co/image/ab67616d0000b273d00821...
# 641  https://i.scdn.co/image/ab67616d0000b273ed50c8...
#
#                              album_name album_release_date  \
# 0                         スーパーハイパー忍者手裏剣         2022-07-13
# 1                                   方向感               2006
# 2                                 NEO-N         2019-10-09
# 3                           STRAY SHEEP         2020-08-05
# 4                                  歹勢好勢         2021-04-30
# ..                                  ...                ...
# 637                           Eyes Open         2006-01-01
# 638  Suzume (Motion Picture Soundtrack)         2022-11-10
# 639                               家和萬事興         2023-06-09
# 640                        燈塔Lighthouse         2022-05-01
# 641                            snowfall         2022-01-14
#
#     album_release_date_precision                             album_uri  \
# 0                            day  spotify:album:32VfvVGwzuka6xQSrdyamD
# 1                           year  spotify:album:0kVzT55moiHLN4Yr3rDGRw
# 2                            day  spotify:album:42VABZoODED0S2Ne4zLCUc
# 3                            day  spotify:album:052EiTRYh35MuDVJN9Emdh
# 4                            day  spotify:album:4tg1ZCJOqMRJAnGT9WdWV7
# ..                           ...                                   ...
# 637                          day  spotify:album:3k7bXPw2u0C0SBKPMsgMS3
# 638                          day  spotify:album:6Ar5HxNWXtvraqs7FI7bYq
# 639                          day  spotify:album:1tZ4awYGvCSGXEUskU7tPY
# 640                          day  spotify:album:5eH0FIug3PloCIxe0fqMFI
# 641                          day  spotify:album:4NRsGHlWBTl4rdLcq8CKcH
#
#                     album_artists  \
# 0                [peanut butters]
# 1                          [1976]
# 2                       [AIRFLIP]
# 3                 [Kenshi Yonezu]
# 4                   [Sorry Youth]
# ..                            ...
# 637                 [Snow Patrol]
# 638  [RADWIMPS, Kazuma Jinnouchi]
# 639                    [Fire EX.]
# 640                         [宋德鶴]
# 641         [Øneheart, reidenshi]
#
#                                    album_external_urls  album_total_tracks  \
# 0    https://open.spotify.com/album/32VfvVGwzuka6xQ...                   1
# 1    https://open.spotify.com/album/0kVzT55moiHLN4Y...                  12
# 2    https://open.spotify.com/album/42VABZoODED0S2N...                  11
# 3    https://open.spotify.com/album/052EiTRYh35MuDV...                  15
# 4    https://open.spotify.com/album/4tg1ZCJOqMRJAnG...                   9
# ..                                                 ...                 ...
# 637  https://open.spotify.com/album/3k7bXPw2u0C0SBK...                  11
# 638  https://open.spotify.com/album/6Ar5HxNWXtvraqs...                  29
# 639  https://open.spotify.com/album/1tZ4awYGvCSGXEU...                  10
# 640  https://open.spotify.com/album/5eH0FIug3PloCIx...                   7
# 641  https://open.spotify.com/album/4NRsGHlWBTl4rdL...                   1
#
#                    artists  disc_number  track_number duration_ms  \
# 0         [peanut butters]            1             1      3m 29s
# 1                   [1976]            1             5      5m 57s
# 2                [AIRFLIP]            1             2      3m 53s
# 3          [Kenshi Yonezu]            1             8      4m 15s
# 4            [Sorry Youth]            1             5       5m 6s
# ..                     ...          ...           ...         ...
# 637          [Snow Patrol]            1             3      4m 27s
# 638             [RADWIMPS]            1            26      5m 55s
# 639             [Fire EX.]            1             3      3m 29s
# 640                  [宋德鶴]            1             5      5m 27s
# 641  [Øneheart, reidenshi]            1             1       2m 4s
#
#     external_ids_isrc                              external_urls_spotify  \
# 0        JPB452205993  https://open.spotify.com/track/5xqxfPEKE3K7Su3...
# 1        TWA470076005  https://open.spotify.com/track/7fopK1NBhSZnRz0...
# 2        JPCO01918630  https://open.spotify.com/track/6vEMm79EkT35v5U...
# 3        JPU901800227  https://open.spotify.com/track/04TshWXkhV1qkqH...
# 4        TWIJ52100005  https://open.spotify.com/track/0ZDCK73eJC4Uyv2...
# ..                ...                                                ...
# 637      GBUM70600345  https://open.spotify.com/track/5hnyJvgoWiQUYZt...
# 638      JPV972200101  https://open.spotify.com/track/4O6htogl2A9ycNL...
# 639      TWBF32306003  https://open.spotify.com/track/5fZanjnTAAoPiV7...
# 640      TWAE32201343  https://open.spotify.com/track/0PyUawLufd6z70G...
# 641      QM3DF2191341  https://open.spotify.com/track/4xF4ZBGPZKxECeD...
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/5xqxfPEKE3K7...
# 1    https://api.spotify.com/v1/tracks/7fopK1NBhSZn...
# 2    https://api.spotify.com/v1/tracks/6vEMm79EkT35...
# 3    https://api.spotify.com/v1/tracks/04TshWXkhV1q...
# 4    https://api.spotify.com/v1/tracks/0ZDCK73eJC4U...
# ..                                                 ...
# 637  https://api.spotify.com/v1/tracks/5hnyJvgoWiQU...
# 638  https://api.spotify.com/v1/tracks/4O6htogl2A9y...
# 639  https://api.spotify.com/v1/tracks/5fZanjnTAAoP...
# 640  https://api.spotify.com/v1/tracks/0PyUawLufd6z...
# 641  https://api.spotify.com/v1/tracks/4xF4ZBGPZKxE...
#
#                    track_id     track_name  track_popularity  \
# 0    5xqxfPEKE3K7Su32bnKtrQ  スーパーハイパー忍者手裏剣                 0
# 1    7fopK1NBhSZnRz0YqDcKry            方向感                27
# 2    6vEMm79EkT35v5UGJbbZ03        Meaning                22
# 3    04TshWXkhV1qkqHzf31Hn6          Lemon                69
# 4    0ZDCK73eJC4Uyv2XjGv1YP           歹勢中年                38
# ..                      ...            ...               ...
# 637  5hnyJvgoWiQUYZttV4wXy6   Chasing Cars                82
# 638  4O6htogl2A9ycNLwc9dVK1  KANATA HALUKA                58
# 639  5fZanjnTAAoPiV75h6iZjQ           火山戀曲                37
# 640  0PyUawLufd6z70GD9vJYQa             斜陽                37
# 641  4xF4ZBGPZKxECeDFrqSAG4       snowfall                85
#
#                                 track_uri video_thumbnail_url
# 0    spotify:track:5xqxfPEKE3K7Su32bnKtrQ                None
# 1    spotify:track:7fopK1NBhSZnRz0YqDcKry                None
# 2    spotify:track:6vEMm79EkT35v5UGJbbZ03                None
# 3    spotify:track:04TshWXkhV1qkqHzf31Hn6                None
# 4    spotify:track:0ZDCK73eJC4Uyv2XjGv1YP                None
# ..                                    ...                 ...
# 637  spotify:track:5hnyJvgoWiQUYZttV4wXy6                None
# 638  spotify:track:4O6htogl2A9ycNLwc9dVK1                None
# 639  spotify:track:5fZanjnTAAoPiV75h6iZjQ                None
# 640  spotify:track:0PyUawLufd6z70GD9vJYQa                None
# 641  spotify:track:4xF4ZBGPZKxECeDFrqSAG4                None
#
# [642 rows x 33 columns]

# %% [markdown]
# #### 熱門藝人

# %%
columns = ['external_urls', 'followers', 'genres', 'href', 'id', 'images', 'name', 'popularity', 'type', 'uri']
top_artists_df = pd.DataFrame(columns=columns)

def extract_artist_info(artist_item):
    return {
        'external_urls': artist_item.get('external_urls', {}).get('spotify'),
        'followers': artist_item.get('followers', {}).get('total'),
        'genres': ', '.join(artist_item.get('genres', [])),
        'href': artist_item.get('href'),
        'id': artist_item.get('id'),
        'images': ', '.join([img['url'] for img in artist_item.get('images', [])]),
        'name': artist_item.get('name'),
        'popularity': artist_item.get('popularity'),
        'type': artist_item.get('type'),
        'uri': artist_item.get('uri')
    }
    
playlist_data = [extract_artist_info(artist_item) for artist_item in top_artists]
top_artists_df = pd.DataFrame(playlist_data, columns=columns)
display(top_artists_df)
# Out:
#                                          external_urls  followers  \
# 0    https://open.spotify.com/artist/7qBIgabdHdcr6N...     105137
# 1    https://open.spotify.com/artist/2elBjNSdBE2Y3f...    5561618
# 2    https://open.spotify.com/artist/3PTsVPijj4pjIo...      83610
# 3    https://open.spotify.com/artist/6c4IBMTcnFDhsK...      46180
# 4    https://open.spotify.com/artist/5XuYYh7VssmjmE...       3988
# ..                                                 ...        ...
# 109  https://open.spotify.com/artist/6rT3tJQmePSMr6...        564
# 110  https://open.spotify.com/artist/7EqcX6VMuJAQVi...        404
# 111  https://open.spotify.com/artist/7qmOAgRUFZhLfw...        416
# 112  https://open.spotify.com/artist/4TcOznbEZBqev2...     388373
# 113  https://open.spotify.com/artist/5hOW2X7ZiiV85j...        899
#
#                                                 genres  \
# 0      mandopop, taiwan indie, taiwan pop, taiwan punk
# 1           c-pop, mandopop, taiwan pop, zhongguo feng
# 2    chinese electropop, mandopop, taiwan indie, ta...
# 3    taiwan indie, taiwan pop, taiwan punk, taiwane...
# 4                            taiwan indie, taiwan punk
# ..                                                 ...
# 109
# 110
# 111
# 112                               mandopop, taiwan pop
# 113
#
#                                                   href  \
# 0    https://api.spotify.com/v1/artists/7qBIgabdHdc...
# 1    https://api.spotify.com/v1/artists/2elBjNSdBE2...
# 2    https://api.spotify.com/v1/artists/3PTsVPijj4p...
# 3    https://api.spotify.com/v1/artists/6c4IBMTcnFD...
# 4    https://api.spotify.com/v1/artists/5XuYYh7Vssm...
# ..                                                 ...
# 109  https://api.spotify.com/v1/artists/6rT3tJQmePS...
# 110  https://api.spotify.com/v1/artists/7EqcX6VMuJA...
# 111  https://api.spotify.com/v1/artists/7qmOAgRUFZh...
# 112  https://api.spotify.com/v1/artists/4TcOznbEZBq...
# 113  https://api.spotify.com/v1/artists/5hOW2X7ZiiV...
#
#                          id  \
# 0    7qBIgabdHdcr6NLujDxWAU
# 1    2elBjNSdBE2Y3f0j1mjrql
# 2    3PTsVPijj4pjIol9yML0rK
# 3    6c4IBMTcnFDhsKHXNSBBvp
# 4    5XuYYh7VssmjmETxEBUF2M
# ..                      ...
# 109  6rT3tJQmePSMr68mPaqyyp
# 110  7EqcX6VMuJAQViJqJrL2yA
# 111  7qmOAgRUFZhLfwtyCGPKdo
# 112  4TcOznbEZBqev21LzAH4KE
# 113  5hOW2X7ZiiV85jFgK4mLlo
#
#                                                 images               name  \
# 0    https://i.scdn.co/image/ab6761610000e5eb6a16f9...           Fire EX.
# 1    https://i.scdn.co/image/ab6761610000e5eb02b3aa...           Jay Chou
# 2    https://i.scdn.co/image/ab6761610000e5eb8a224a...        Astro Bunny
# 3    https://i.scdn.co/image/ab6761610000e5eb2f1c8d...        Sorry Youth
# 4    https://i.scdn.co/image/ab6761610000e5eb2cb915...          EmptyORio
# ..                                                 ...                ...
# 109  https://i.scdn.co/image/ab6761610000e5eb2c6b88...  Garden Collective
# 110  https://i.scdn.co/image/ab6761610000e5ebc1d07e...          Hers Lake
# 111  https://i.scdn.co/image/ab6761610000e5eb3182fe...        Isaak Young
# 112  https://i.scdn.co/image/ab6761610000e5eb4d8331...            高爾宣 OSN
# 113  https://i.scdn.co/image/ab6761610000e5eb2a1660...          Imala Zir
#
#      popularity    type                                    uri
# 0            44  artist  spotify:artist:7qBIgabdHdcr6NLujDxWAU
# 1            69  artist  spotify:artist:2elBjNSdBE2Y3f0j1mjrql
# 2            37  artist  spotify:artist:3PTsVPijj4pjIol9yML0rK
# 3            35  artist  spotify:artist:6c4IBMTcnFDhsKHXNSBBvp
# 4            14  artist  spotify:artist:5XuYYh7VssmjmETxEBUF2M
# ..          ...     ...                                    ...
# 109          43  artist  spotify:artist:6rT3tJQmePSMr68mPaqyyp
# 110          44  artist  spotify:artist:7EqcX6VMuJAQViJqJrL2yA
# 111          43  artist  spotify:artist:7qmOAgRUFZhLfwtyCGPKdo
# 112          54  artist  spotify:artist:4TcOznbEZBqev21LzAH4KE
# 113          45  artist  spotify:artist:5hOW2X7ZiiV85jFgK4mLlo
#
# [114 rows x 10 columns]

# %% [markdown]
# #### 熱門曲目

# %%
columns = [
    'album_type', 'artists_href', 'artists_id', 'artists_name', 'artists_type', 'artists_uri', 'artists_available_markets',
    'album_href', 'album_id', 'album_image', 'album_name', 'release_date', 'release_date_precision', 'total_tracks', 'album_uri',
    'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'track_href', 'track_id', 'track_is_local', 'track_name',
    'popularity', '30_seconds_music', 'track_type', 'track_uri'
    ]
top_tracks_df = pd.DataFrame(columns=columns)

def extract_track_info(track_item):
    album = track_item['album']
    artists = track_item['artists']
    first_artist = artists[0] if artists else {}
    
    return {
        'album_type': album.get('album_type', ''),
        'artists_href': first_artist.get('href', ''),
        'artists_id': first_artist.get('id', ''),
        'artists_name': first_artist.get('name', ''),
        'artists_type': first_artist.get('type', ''),
        'artists_uri': first_artist.get('uri', ''),
        'artists_available_markets': album.get('available_markets', []),
        'album_href': album.get('href', ''),
        'album_id': album.get('id', ''),
        'album_image': album['images'][0]['url'] if album.get('images') else '',
        'album_name': album.get('name', ''),
        'release_date': album.get('release_date', ''),
        'release_date_precision': album.get('release_date_precision', ''),
        'total_tracks': album.get('total_tracks', 0),
        'album_uri': album.get('uri', ''),
        'album_available_markets': track_item.get('available_markets', []),
        'disc_number': track_item.get('disc_number', 0),
        'duration_ms': track_item.get('duration_ms', 0),
        'explicit': track_item.get('explicit', False),
        'external_ids': track_item['external_ids'].get('isrc', '') if track_item.get('external_ids') else '',
        'track_href': track_item.get('href', ''),
        'track_id': track_item.get('id', ''),
        'track_is_local': track_item.get('is_local', False),
        'track_name': track_item.get('name', ''),
        'popularity': track_item.get('popularity', 0),
        '30_seconds_music': track_item.get('preview_url', ''),
        'track_type': track_item.get('type', ''),
        'track_uri': track_item.get('uri', '')
    }
    
extracted_data = [extract_track_info(track) for track in top_tracks]
top_tracks_df = pd.DataFrame(extracted_data)
top_tracks_df['duration_ms'] = pd.to_timedelta(top_tracks_df['duration_ms'], unit='ms').apply(lambda x: f"{x.components.minutes}m {x.components.seconds}s")

display(top_tracks_df)
# Out:
#      album_type                                       artists_href  \
# 0         ALBUM  https://api.spotify.com/v1/artists/7qBIgabdHdc...
# 1         ALBUM  https://api.spotify.com/v1/artists/7qBIgabdHdc...
# 2         ALBUM  https://api.spotify.com/v1/artists/3Xp3DA50zRP...
# 3        SINGLE  https://api.spotify.com/v1/artists/3PTsVPijj4p...
# 4         ALBUM  https://api.spotify.com/v1/artists/6FGSUph2Uv0...
# ...         ...                                                ...
# 1338      ALBUM  https://api.spotify.com/v1/artists/6ft7JnxMyZh...
# 1339      ALBUM  https://api.spotify.com/v1/artists/3mgkHRW7Rgk...
# 1340      ALBUM  https://api.spotify.com/v1/artists/3HXSUfI76zV...
# 1341     SINGLE  https://api.spotify.com/v1/artists/51sob9QZyfL...
# 1342      ALBUM  https://api.spotify.com/v1/artists/3b0TLzX6Fke...
#
#                   artists_id           artists_name artists_type  \
# 0     7qBIgabdHdcr6NLujDxWAU               Fire EX.       artist
# 1     7qBIgabdHdcr6NLujDxWAU               Fire EX.       artist
# 2     3Xp3DA50zRP4TYOtNR7k1T              Soft Lipa       artist
# 3     3PTsVPijj4pjIol9yML0rK            Astro Bunny       artist
# 4     6FGSUph2Uv0yi2oM1hDV78              I Mean Us       artist
# ...                      ...                    ...          ...
# 1338  6ft7JnxMyZhp7N52qzHymY                Vansire       artist
# 1339  3mgkHRW7Rgkbx2gJb5TPl7         Wayne's so Sad       artist
# 1340  3HXSUfI76zVZk71UMAeVfp  No Party For Cao Dong       artist
# 1341  51sob9QZyfLff9XqvYluN5                Sezairi       artist
# 1342  3b0TLzX6FkeQvv9daBtFBe                  Goson       artist
#
#                                 artists_uri  \
# 0     spotify:artist:7qBIgabdHdcr6NLujDxWAU
# 1     spotify:artist:7qBIgabdHdcr6NLujDxWAU
# 2     spotify:artist:3Xp3DA50zRP4TYOtNR7k1T
# 3     spotify:artist:3PTsVPijj4pjIol9yML0rK
# 4     spotify:artist:6FGSUph2Uv0yi2oM1hDV78
# ...                                     ...
# 1338  spotify:artist:6ft7JnxMyZhp7N52qzHymY
# 1339  spotify:artist:3mgkHRW7Rgkbx2gJb5TPl7
# 1340  spotify:artist:3HXSUfI76zVZk71UMAeVfp
# 1341  spotify:artist:51sob9QZyfLff9XqvYluN5
# 1342  spotify:artist:3b0TLzX6FkeQvv9daBtFBe
#
#                               artists_available_markets  \
# 0     [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 1     [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 2     [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 3     [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 4     [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# ...                                                 ...
# 1338  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 1339  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 1340  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 1341  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 1342  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
#
#                                              album_href  \
# 0     https://api.spotify.com/v1/albums/2PkESw7qmj3V...
# 1     https://api.spotify.com/v1/albums/085Z2SYvqoao...
# 2     https://api.spotify.com/v1/albums/4yw85NDJ9SkY...
# 3     https://api.spotify.com/v1/albums/1FvL5S6imtz7...
# 4     https://api.spotify.com/v1/albums/5azoxbgGTCqw...
# ...                                                 ...
# 1338  https://api.spotify.com/v1/albums/7CESHttY9U97...
# 1339  https://api.spotify.com/v1/albums/3mJ7fOuXGDbo...
# 1340  https://api.spotify.com/v1/albums/4jG9BnjtTMtt...
# 1341  https://api.spotify.com/v1/albums/0HUPU7ZBkyRz...
# 1342  https://api.spotify.com/v1/albums/4kO2Enxd9XSV...
#
#                     album_id  \
# 0     2PkESw7qmj3Vc4X2R4KSPy
# 1     085Z2SYvqoao1GwcdidsS7
# 2     4yw85NDJ9SkYVMxBOwqx4Z
# 3     1FvL5S6imtz7bYXjdOlWgv
# 4     5azoxbgGTCqwqgpiirrctu
# ...                      ...
# 1338  7CESHttY9U97FElD5JAXSW
# 1339  3mJ7fOuXGDbo3F4FGyBna0
# 1340  4jG9BnjtTMttg9E3sfg1B8
# 1341  0HUPU7ZBkyRzwn6iLxbfF0
# 1342  4kO2Enxd9XSVt4KNQpqqIv
#
#                                             album_image          album_name  \
# 0     https://i.scdn.co/image/ab67616d0000b2739ddf8d...               進擊下半場
# 1     https://i.scdn.co/image/ab67616d0000b2734f55ec...              Reborn
# 2     https://i.scdn.co/image/ab67616d0000b273002a90...                 收斂水
# 3     https://i.scdn.co/image/ab67616d0000b273f9ec23...         你已忘記但我還記得的事
# 4     https://i.scdn.co/image/ab67616d0000b27351b586...                 OST
# ...                                                 ...                 ...
# 1338  https://i.scdn.co/image/ab67616d0000b273a78876...         Angel Youth
# 1339  https://i.scdn.co/image/ab67616d0000b273f8f5cc...               無名氏敬上
# 1340  https://i.scdn.co/image/ab67616d0000b2731fb78b...                  瓦合
# 1341  https://i.scdn.co/image/ab67616d0000b273aef301...                70's
# 1342  https://i.scdn.co/image/ab67616d0000b27396b725...  Garden of Serenity
#
#      release_date release_date_precision  total_tracks  \
# 0      2017-04-14                    day            21
# 1      2016-03-25                    day            12
# 2      2009-07-22                    day            14
# 3      2020-11-25                    day             1
# 4      2018-08-24                    day             8
# ...           ...                    ...           ...
# 1338   2018-04-26                    day            17
# 1339   2023-09-07                    day            15
# 1340   2023-05-20                    day            11
# 1341   2017-07-07                    day             1
# 1342   2024-02-05                    day            12
#
#                                  album_uri  \
# 0     spotify:album:2PkESw7qmj3Vc4X2R4KSPy
# 1     spotify:album:085Z2SYvqoao1GwcdidsS7
# 2     spotify:album:4yw85NDJ9SkYVMxBOwqx4Z
# 3     spotify:album:1FvL5S6imtz7bYXjdOlWgv
# 4     spotify:album:5azoxbgGTCqwqgpiirrctu
# ...                                    ...
# 1338  spotify:album:7CESHttY9U97FElD5JAXSW
# 1339  spotify:album:3mJ7fOuXGDbo3F4FGyBna0
# 1340  spotify:album:4jG9BnjtTMttg9E3sfg1B8
# 1341  spotify:album:0HUPU7ZBkyRzwn6iLxbfF0
# 1342  spotify:album:4kO2Enxd9XSVt4KNQpqqIv
#
#                                 album_available_markets  disc_number  \
# 0     [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 1     [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 2     [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 3     [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 4     [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# ...                                                 ...          ...
# 1338  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 1339  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 1340  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 1341  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
# 1342  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...            1
#
#      duration_ms  explicit  external_ids  \
# 0          3m 6s     False  TWBF31704020
# 1          4m 9s     False  TWBF31603009
# 2         5m 16s      True  TWI450900005
# 3         3m 51s     False  TWA452000058
# 4         5m 25s     False  TWP011840607
# ...          ...       ...           ...
# 1338       3m 1s     False  QZAPG1809214
# 1339      1m 55s     False  TWAE32300473
# 1340      3m 46s     False  TWKH12300008
# 1341      3m 30s     False  SGSM15100047
# 1342      2m 21s     False  UKZGC2309751
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/2DZLyqxPBCzi...
# 1     https://api.spotify.com/v1/tracks/5DtVMfHHv0gH...
# 2     https://api.spotify.com/v1/tracks/13tJ9Mkj7cjX...
# 3     https://api.spotify.com/v1/tracks/1Et2Gm6vcU79...
# 4     https://api.spotify.com/v1/tracks/6desVkqsKDt0...
# ...                                                 ...
# 1338  https://api.spotify.com/v1/tracks/2SqEopjZJjyA...
# 1339  https://api.spotify.com/v1/tracks/5NlT8Q2Sc54Z...
# 1340  https://api.spotify.com/v1/tracks/6DQYFsOi8HcY...
# 1341  https://api.spotify.com/v1/tracks/70RenFMioRIy...
# 1342  https://api.spotify.com/v1/tracks/7MI1zzeLGVnU...
#
#                     track_id  track_is_local           track_name  popularity  \
# 0     2DZLyqxPBCziw1YJOWPCjQ           False                 長途夜車          52
# 1     5DtVMfHHv0gHgwOtPoxMcT           False                繼續向前行          32
# 2     13tJ9Mkj7cjXxrTjOh0LAN           False                 關於小熊          50
# 3     1Et2Gm6vcU79f2nBndPmno           False          你已忘記但我還記得的事          20
# 4     6desVkqsKDt0ZHLqPcWcbZ           False  You So (Youth Soul)          33
# ...                      ...             ...                  ...         ...
# 1338  2SqEopjZJjyAAp2nFkJi7i           False      Nice to See You          54
# 1339  5NlT8Q2Sc54Ztm6GgyJx4Q           False                第一道微風          31
# 1340  6DQYFsOi8HcYoCuqKPYSFq           False                    八          44
# 1341  70RenFMioRIy5u2eVYJZqh           False                 70's          21
# 1342  7MI1zzeLGVnUwq87u4RdoZ           False           Moonflower          44
#
#                                        30_seconds_music track_type  \
# 0     https://p.scdn.co/mp3-preview/60c3733785fded9f...      track
# 1     https://p.scdn.co/mp3-preview/63d985bd90be04b8...      track
# 2     https://p.scdn.co/mp3-preview/77ce0222c53af326...      track
# 3     https://p.scdn.co/mp3-preview/ede1b682d01e8ddb...      track
# 4     https://p.scdn.co/mp3-preview/dd23af707a3fdc83...      track
# ...                                                 ...        ...
# 1338  https://p.scdn.co/mp3-preview/d981646961ee7e15...      track
# 1339  https://p.scdn.co/mp3-preview/181572adc32ce5c2...      track
# 1340  https://p.scdn.co/mp3-preview/fd9bdbece86b4567...      track
# 1341  https://p.scdn.co/mp3-preview/7cf7bace0f52abeb...      track
# 1342  https://p.scdn.co/mp3-preview/7be0d4d1cf6921c6...      track
#
#                                  track_uri
# 0     spotify:track:2DZLyqxPBCziw1YJOWPCjQ
# 1     spotify:track:5DtVMfHHv0gHgwOtPoxMcT
# 2     spotify:track:13tJ9Mkj7cjXxrTjOh0LAN
# 3     spotify:track:1Et2Gm6vcU79f2nBndPmno
# 4     spotify:track:6desVkqsKDt0ZHLqPcWcbZ
# ...                                    ...
# 1338  spotify:track:2SqEopjZJjyAAp2nFkJi7i
# 1339  spotify:track:5NlT8Q2Sc54Ztm6GgyJx4Q
# 1340  spotify:track:6DQYFsOi8HcYoCuqKPYSFq
# 1341  spotify:track:70RenFMioRIy5u2eVYJZqh
# 1342  spotify:track:7MI1zzeLGVnUwq87u4RdoZ
#
# [1343 rows x 28 columns]

# %%
top_tracks_df_str = top_tracks_df.astype(str)
duplicates = top_tracks_df_str.duplicated(keep=False)
duplicate_rows = top_tracks_df_str[duplicates]
print("重複的行：")
print(duplicate_rows)

has_duplicates = duplicates.any()
num_duplicates = duplicates.sum()
print(f"是否有重複行：{has_duplicates}")
print(f"重複行的數量：{num_duplicates}")
# Out:
# 重複的行：
# Empty DataFrame
# Columns: [album_type, artists_href, artists_id, artists_name, artists_type, artists_uri, artists_available_markets, album_href, album_id, album_image, album_name, release_date, release_date_precision, total_tracks, album_uri, album_available_markets, disc_number, duration_ms, explicit, external_ids, track_href, track_id, track_is_local, track_name, popularity, 30_seconds_music, track_type, track_uri]
# Index: []
# 是否有重複行：False
# 重複行的數量：0

# %% [markdown]
# #### 獲取歌曲特色

# %%
def extract_track_feature_info(id):
    global access_token
    if datetime.now() > datetime.fromtimestamp(session['expires_at']):
        refresh_access_token()
    
    headers = {'Authorization': f'Bearer {access_token}'}
    
    response = requests.get(f'https://api.spotify.com/v1/audio-features/{id}', headers=headers).json()

    
    return response  

tracks_feature = []
for i in range(len(playlists_df['track_id'])):
    tracks_feature.append(extract_track_feature_info(playlists_df['track_id'][i]))

# %%
tracks_feature_df = pd.DataFrame(tracks_feature).drop(columns={'type', 'uri', 'duration_ms'})
filter_top_tracks_df = playlists_df[[
                                    'added_at', 'added_by', 'track_preview_url', 'track_available_markets', 'explicit',
                                    'album_available_markets',  'album_type', 'album_href', 'album_id', 'album_image_url', 'album_name',
                                    'album_release_date', 'album_release_date_precision', 'album_uri', 'album_artists', 'album_external_urls',
                                    'album_total_tracks', 'artists', 'disc_number', 'track_number', 'duration_ms', 'external_ids_isrc',
                                    'external_urls_spotify', 'track_id', 'track_name', 'track_popularity', 'track_uri'
                                ]].rename(columns={'track_id': 'id'})
total_feature_info_df = pd.merge(tracks_feature_df, filter_top_tracks_df, on='id', how='inner')

# %%
high_pop_data = total_feature_info_df[total_feature_info_df['track_popularity'] > total_feature_info_df['track_popularity'].mean()]
high_pop_features_mean = high_pop_data[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']].mean()
overall_features_mean = total_feature_info_df[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']].mean()
display(high_pop_features_mean, overall_features_mean)

# 從這些數據中可以得出，相比於所有曲目，高流行度曲目通常具有更高的舞動性、較低的能量、較低的響度、更接近原聲、較於正向、幾乎都是有人聲的音樂。
# Out:
# danceability          0.553856
# energy                0.660648
# loudness             -6.699718
# speechiness           0.050953
# acousticness          0.212608
# instrumentalness      0.026192
# liveness              0.178646
# valence               0.422304
# tempo               123.987874
# dtype: float64
# danceability          0.527271
# energy                0.680868
# loudness             -6.548672
# speechiness           0.048203
# acousticness          0.192059
# instrumentalness      0.050608
# liveness              0.169375
# valence               0.417205
# tempo               124.187732
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns


audio_features = ['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']

plt.figure(figsize=(15, 12))
sns.set_style('whitegrid')

for i, feature in enumerate(audio_features, 1):
    plt.subplot(3, 3, i)
    sns.histplot(total_feature_info_df[feature], kde=True, color='blue', bins=30)
    plt.title(f'{feature.capitalize()} Distribution')
    plt.xlabel(feature.capitalize())
    plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %%
correlation_matrix = total_feature_info_df[audio_features].corr()

plt.figure(figsize=(30, 15))
plt.rcParams['font.size'] = 16  # 基本字體大小
sns.set_style('whitegrid')
heatmap = sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
heatmap.set_title('Correlation Matrix of Track Features', fontsize=28, pad=20)
plt.show()

# %%
# from yellowbrick.cluster import KElbowVisualizer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans


data_clustering = total_feature_info_df[audio_features]

scaler = StandardScaler()
data_clustering_scaled = scaler.fit_transform(data_clustering)

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=42)
    kmeans.fit(data_clustering_scaled)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
clusters = kmeans.fit_predict(data_clustering_scaled)
total_feature_info_df['cluster'] = clusters

# %%
columns = audio_features + ['cluster']
cluster_means = total_feature_info_df[columns].groupby('cluster').mean()
cluster_means


# 群組 0
# 特點：適合跳舞的程度較低，音樂強度高，音量大，中等的自白話語和原聲性。
# 音樂風格：強烈且有節奏感的音樂，適合需要高能量背景音樂的場合，如運動或某些競賽活動。
# 群組 1
# 特點：適合跳舞的程度較高，音樂強度高，音量大，原聲性較明顯。
# 音樂風格：活力充沛且具有親和力的音樂，適合舞會和社交活動，能夠激發積極的情感和氛圍。
# 群組 2
# 特點：適合跳舞的程度中等，音樂強度非常高，自白話語相當多，極低的原聲性。
# 音樂風格：節奏快速且富有攻擊性的音樂，可能包括大量的電子元素和饒舌，適合現場表演和活力爆發的場合。
# 群組 3
# 特點：適合跳舞的程度中等，音樂強度低，音量小，非常高的原聲性和接近純音樂。(參數在0.5以上會被歸類為純音樂)
# 音樂風格：情緒深沉且具有藝術性的音樂，大量使用樂器鋪陳歌曲，適合安靜聆聽和反思，如咖啡廳背景音樂或獨自放鬆時聆聽。
# Out:
#          danceability    energy  loudness  speechiness  acousticness  \
# cluster
# 0            0.429113  0.771010 -5.336340     0.049062      0.041465
# 1            0.575652  0.753500 -5.686848     0.040458      0.113670
# 2            0.531267  0.895400 -4.507000     0.171833      0.029210
# 3            0.554842  0.463196 -9.193752     0.039600      0.467981
#
#          instrumentalness  liveness   valence       tempo
# cluster
# 0                0.042295  0.155495  0.417046  154.551959
# 1                0.006561  0.167652  0.510341  104.295884
# 2                0.010993  0.381127  0.581867  150.384400
# 3                0.124658  0.153611  0.265650  118.314416

# %%
key_mode_grouped = total_feature_info_df.groupby(['key', 'mode']).agg({'danceability': 'mean', 'energy': 'mean', 'valence': 'mean', 'loudness': 'mean', 'track_popularity': 'mean'}).reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(data=key_mode_grouped, x='key', y='track_popularity', hue='mode', palette='muted')
plt.title('How Music Key and Mode Influence Track Popularity', fontsize=18)
plt.xlabel('Key', fontsize=14)
plt.ylabel('Track Popularity', fontsize=14)
plt.legend(title='Mode', labels=['Minor Mode', 'Major Mode'])
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# 這張圖表顯示了不同音調和音調模式（0=小調, 1=大調）的曲目的平均流行度。
# 可以看到音調之間流行度的差異，其中某些調性的大調通常比小調更受歡迎，反之亦然。這可能與音調的情感表達有關，大調通常被認為更快樂和正面。

# %% [markdown]
# #### 獲取歌曲排名

# %%
id = '0jz8mea3EKbqvOxZY6skBz' # 怕胖團
country = 'TW'
api_link = f'https://api.spotify.com/v1/artists/{id}/top-tracks?market={country}'
headers = {'Authorization': 'Bearer ' + access_token}
res = requests.get(api_link, headers = headers).json()

# %%
df = pd.DataFrame()
for i in range(len(res['tracks'])):
  album = res['tracks'][i]['album']['name']
  song = res['tracks'][i]['name']
  popularity = res['tracks'][i]['popularity']
  result = pd.DataFrame({'album': [album], 'song': [song], 'popularity': [popularity]})
  df = pd.concat([df, result], ignore_index = True)

# %%
df = (df
      .sort_values(by = 'popularity', ascending = False)
      .reset_index()
      .drop('index', axis = 1))
df
# Out:
#             album              song  popularity
# 0          青春只差兩撇                 魚          52
# 1            2049              月旁月光          46
# 2            2049  我沒有用, 沒辦法給你想要的生活          45
# 3  原來你跟每個人都說著一樣的話    原來你跟每個人都說著一樣的話          44
# 4               V           請記得揍我一拳          43
# 5       當你在最需要的時候         當你在最需要的時候          41
# 6            2049               後照鏡          39
# 7             痞得胖              流浪王子          36
# 8          青春只差兩撇             想想當初吧          36
# 9   Keep Fighting     Keep Fighting          35
